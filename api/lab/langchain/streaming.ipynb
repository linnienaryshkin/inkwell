# %%
print("Hello World!")
# Out:
# Hello World!

# %%
from dotenv import load_dotenv

# Load environment variables from .env
load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(model="claude-haiku-4-5", system_prompt="You are a full-stack comedian")

# %%
# Stream = values
for step in agent.stream(
    {"messages": [{"role": "user", "content": "Tell me a Dad joke"}]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Tell me a Dad joke
# ================================== Ai Message ==================================
#
# Why don't scientists trust atoms?
#
# Because they make up everything! 😄

# %%
for token, metadata in agent.stream(
    {"messages": [{"role": "user", "content": "Write me a family friendly poem."}]},
    stream_mode="messages",
):
    print(f"{token.content}", end="")
# Out:
# # A Day Together
#
# When morning breaks with golden light,
# And everyone's in cheerful sight,
# We gather 'round the table wide,
# With laughter ringing far and wide.
#
# The little ones with messy faces,
# Chase each other through the spaces,
# While someone tells a silly joke,
# That makes us all burst into smoke!
#
# We play some games and take a walk,
# Through neighborhoods, we skip and talk,
# The dog runs circles all around,
# His happy barks the sweetest sound.
#
# At dinner time we share our days,
# In a hundred different ways,
# Then snuggled up we'll watch the stars,
# And count the passing cars and cars.
#
# No matter what the world may bring,
# When we're together, hearts take wing,
# For family time, both big and small,
# Is quite the greatest gift of all.
#
# ---
#
# Hope this brings some smiles! 😄
