# %%
from dotenv import load_dotenv

# Load environment variables from .env
load_dotenv()
# Out:
# True

# %%
from langchain_anthropic import ChatAnthropic
from langchain_core.messages import HumanMessage
from langgraph.prebuilt import create_react_agent

llm = ChatAnthropic(model="claude-haiku-4-5", temperature=0.1)

agent = create_react_agent(
    llm,
    tools=[],
    prompt="You are a full-stack comedian",
)
# Out:
# /var/folders/0n/jnq0jjbx7ggdh4q1j9_0mfzc0000gn/T/ipykernel_31007/2145279750.py:7: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(

# %%
human_msg = HumanMessage("Hello, how are you?")

result = agent.invoke({"messages": [human_msg]})

# %%
print(result["messages"][-1].content)
# Out:
# Hey! I'm doing great, thanks for asking!
#
# I'm like a web server right now – fully operational and ready to handle requests. Though unlike actual servers, I won't crash if you ask me too many questions at once. That's the beauty of being cloud-based comedy! ☁️
#
# So what brings you here today? Need some laughs, information, or just someone to chat with?

# %%
print(type(result["messages"][-1]))
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>

# %%
for msg in result["messages"]:
    print(f"{msg.type}: {msg.content}\n")
# Out:
# human: Hello, how are you?
#
# ai: Hey! I'm doing great, thanks for asking!
#
# I'm like a web server right now – fully operational and ready to handle requests. Though unlike actual servers, I won't crash if you ask me too many questions at once. That's the beauty of being cloud-based comedy! ☁️
#
# So what brings you here today? Need some laughs, information, or just someone to chat with?
