# %%
from dotenv import load_dotenv

# Load environment variables from .env
load_dotenv()
# Out:
# True

# %%
import nest_asyncio
from langchain_mcp_adapters.client import MultiServerMCPClient

nest_asyncio.apply()

# Connect to the mcp-time server for timezone-aware operations
# This Go-based server provides tools for current time, relative time parsing,
# timezone conversion, duration arithmetic, and time comparison
mcp_client = MultiServerMCPClient(
    {
        "time": {
            "transport": "stdio",
            "command": "npx",
            "args": ["-y", "@theo.foobar/mcp-time"],
        }
    },
)

# Load tools from the MCP server
mcp_tools = await mcp_client.get_tools()
print(f"Loaded {len(mcp_tools)} MCP tools: {[t.name for t in mcp_tools]}")
# Out:
# Loaded 5 MCP tools: ['add_time', 'compare_time', 'convert_timezone', 'current_time', 'relative_time']

# %%
from langchain.agents import create_agent

agent_with_mcp = create_agent(
    model="claude-haiku-4-5",
    tools=mcp_tools,
    system_prompt="You are a helpful assistant",
)

# %%
result = await agent_with_mcp.ainvoke(
    {"messages": [{"role": "user", "content": "What's the time in Vilnius right now?"}]}
)
for msg in result["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What's the time in Vilnius right now?
# ================================== Ai Message ==================================
#
# [{'id': 'toolu_01TX736eubMSKs1s8ksJwBnZ', 'caller': {'type': 'direct'}, 'input': {'timezone': 'Europe/Vilnius'}, 'name': 'current_time', 'type': 'tool_use'}]
# Tool Calls:
#   current_time (toolu_01TX736eubMSKs1s8ksJwBnZ)
#  Call ID: toolu_01TX736eubMSKs1s8ksJwBnZ
#   Args:
#     timezone: Europe/Vilnius
# ================================= Tool Message =================================
# Name: current_time
#
# [{'type': 'text', 'text': '2026-04-13T18:19:22+03:00', 'id': 'lc_721e52b5-c7da-437b-ab90-753f8d71c23f'}]
# ================================== Ai Message ==================================
#
# The current time in Vilnius is **18:19:22** (6:19 PM and 22 seconds) on April 13, 2026. The timezone is UTC+3.
